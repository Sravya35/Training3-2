# %%
text = "NLP is very interesting"
tokens = text.split()
print(tokens)
# Out:
# ['NLP', 'is', 'very', 'interesting']

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sravy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
text1="Welcome to Mru"
word_tokenize(text1)
# Out:
# ['Welcome', 'to', 'Mru']

# %%
from nltk.tokenize import sent_tokenize

text = "Welcome to 3-2 Training. NLP is very intresting."
sent_tokenize(text)
# Out:
# ['Welcome to 3-2 Training.', 'NLP is very intresting.']

# %%
from nltk.tokenize import WordPunctTokenizer

tokenizer = WordPunctTokenizer()
tokenizer.tokenize("Let's see how it's working.")
# Out:
# ['Let', "'", 's', 'see', 'how', 'it', "'", 's', 'working', '.']

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
text = "Let's see how it's working."
tokenizer.tokenize(text)
# Out:
# ['Let', 's', 'see', 'how', 'it', 's', 'working']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sravy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
print(stop_words[:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
