# %%
import numpy as np
data=np.array([34,67,89,90,65,98,64])
np.mean(data)
# Out:
# 72.42857142857143

# %%
np.median(data)
# Out:
# 67.0

# %%
np.std(data)
# Out:
# 20.247448818887513

# %%
np.var(data)
# Out:
# 511.03999999999996

# %%
data = [2, 4, 6, 8, 10]
mean = sum(data) / len(data)
print(mean)
# Out:
# 6.0

# %%
data.sort()
n = len(data)

median = data[n//2] if n % 2 != 0 else (data[n//2 - 1] + data[n//2]) / 2

print(median)
# Out:
# 6

# %%
mean = sum(data) / len(data)
var = sum((x - mean) ** 2 for x in data) / len(data)

print(var)
# Out:
# 8.0

# %%
mean = sum(data) / len(data)
std = (sum((x - mean) ** 2 for x in data) / len(data)) ** 0.5

print(std)
# Out:
# 2.8284271247461903

# %%
data = [8, 2, 10, 4, 6]
n = len(data)

# Bubble sort
for i in range(n):
    for j in range(0, n - i - 1):
        if data[j] > data[j + 1]:
            data[j], data[j + 1] = data[j + 1], data[j]

# %%
median = data[n//2] if n % 2 != 0 else (data[n//2 - 1] + data[n//2]) / 2

print(median)
# Out:
# 6
